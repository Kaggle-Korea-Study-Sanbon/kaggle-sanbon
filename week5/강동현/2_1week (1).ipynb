# %% [markdown]
# # 1.. 확률이란
#
# - 정리, 묘사, 기술을 해왔던 것으로부터 무언가를 알아내는 추론으로 가기 위한 중간 과정
#
# - 불확실성의 성격을 가짐.

# %% [markdown]
# # 2. 확률을 보는 두가지 견해

# %% [markdown]
# 1. **도수이론**
#
# - 확률이란, 한 시행을 동일한 조건 하에서 독립적으로 반복할 때 그 사건이 일어날 것으로 예측되는 횟수의 전체 시행횟수에 대한 백분율.
#
# - 경험적인 확률의 극한으로써 확률을 이해하는 것.
#
# 2. **주관적 견해**
#
# - 확률이란, 사건에 대한 주관적 확신의 정도.
#
# - 반복시행 여부와 관계없이 정의됨.

# %% [markdown]
# #3. 확률의 특징
# 1. 상호배반
#
# - 한 사건이 발생할 때 다른 사건이 함께 발생할 수 없는 경우 두 사건은 '상호배반' or '배반' 관계라고 함.

# %%
from google.colab import files
uploaded = files.upload() 

for fn in uploaded.keys(): 
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-929698d8-6419-4367-8860-577c093fc2b7" name="files[]" multiple disabled />
#      <output id="result-929698d8-6419-4367-8860-577c093fc2b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving week4.PNG to week4.PNG
# User uploaded file "week4.PNG" with length 307397 bytes

# %%
from IPython.display import Image
Image('week1.PNG')

# %% [markdown]
# 2. 조건부 확률
#
# - 어떤 사건 B가 일어났다고 가정했을 때에 사건 A가 일어날 확률을 의미함.

# %%
from IPython.display import Image
Image('week2.PNG')

# %% [markdown]
# 3. 독립
#
# - 두 사건이 독립이라는 것은, 둘 중 하나의 사건이 일어날 확률이 다른 사건이 일어날 확률에 영향을 미치지 않는다는 것을 의미
#
# - 그렇지 않은 경우, 두 사건의 관계는 '종속'
#
# - 복원 추출 = 독립 / 비복원 추출 = 종속

# %%
from IPython.display import Image
Image('week3.PNG')

# %% [markdown]
# 4. 분할
#
# - 그 안에 있는 부분 집합들을, 원소들을 다 합치면 전체가 커버가 되며, 그 안에 있는 원소들 사이에 겹치는 게 없음
#
# - 예시) 전체 인구 중, 남성과 여성 인구

# %% [markdown]
# 5. 베이즈 정리
#
# - 사건 A, 사건 B가 있을 때, 사건 B가 일어난 것을 전제로 한 사건 A의 조건부 확률을 구하는 것

# %%
from IPython.display import Image
Image('week4.PNG')

# %% [markdown]
# 사용 이유
#
# - 기존: 모집단을 변하지 않은 대상으로 봄
#
# - 베이즈: 모집단을 미리 확정짓지 않음.
#
# 즉, 정보가 증가됨에 따라 업데이팅이 가능함.
#
#
#
# 사전 정보
# : P(A1), … P(An)을 의미
#
# 사후 정보 : P(Ak|B)
