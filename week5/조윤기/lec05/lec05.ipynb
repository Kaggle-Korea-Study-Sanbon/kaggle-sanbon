# %% [markdown]
# # Lec 05. Tensorflow 로 Logistic Classification 구현하기

# %% [markdown]
# ## Hypothesis using sigmoid, New cost function and Gradient Descent
# ![](lec05.assets/image1.png)

# %%
import tensorflow as tf

# %% [markdown]
# ## Training Data

# %%
x_data = [[1,2], [2,3], [3,1], [4,3], [5,3], [6,2]]
y_data = [[0], [0], [0], [1], [1], [1]]

# placeholders for a tensor that will be always fed.
X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([2,1], name='weight'))
b = tf.Variable(tf.random_normal([1], name='bias'))

# Hypothesis using sigmoid
# same with, tf.div(1., 1. + tf.exp(tf.matmul(X, W) + b))
hypothesis = tf.sigmoid(tf.matmul(X, W) + b)

# new cost/loss function
cost = -tf.reduce_mean(Y*tf.log(hypothesis) + (1-Y)*tf.log(1-hypothesis))

# gradient descent
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)

# Accuracy computation
# True if hypothesis>0.5 else False
predicted = tf.cast(hypothesis>0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Launch graph using 'with statement'
with tf.Session() as sess:
    # initialize tensorflow variables
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        _cost, _ = sess.run([cost, train], feed_dict={X:x_data,
                                                      Y:y_data})
        if step % 200 == 0:
            print(f'{step} step\n  Cost: {_cost}\n')
            
    # Accuracy report
    _h, _c, _a = sess.run([hypothesis, predicted, accuracy],
                          feed_dict={X:x_data, Y:y_data})
    print(f'Hypothesis:\n{_h}\nPredict:\n{_c}\nAccuracy: {_a}\n')
# Out:
# 0 step
#   Cost: 0.633888840675354
#
# 200 step
#   Cost: 0.5965915322303772
#
# 400 step
#   Cost: 0.5677077174186707
#
# 600 step
#   Cost: 0.5416492819786072
#
# 800 step
#   Cost: 0.5180893540382385
#
# 1000 step
#   Cost: 0.4966790974140167
#
# 1200 step
#   Cost: 0.4770852029323578
#
# 1400 step
#   Cost: 0.4590155780315399
#
# 1600 step
#   Cost: 0.44223031401634216
#
# 1800 step
#   Cost: 0.4265415668487549
#
# 2000 step
#   Cost: 0.411805659532547
#
# 2200 step
#   Cost: 0.3979139029979706
#
# 2400 step
#   Cost: 0.3847833573818207
#
# 2600 step
#   Cost: 0.3723491132259369
#
# 2800 step
#   Cost: 0.3605585992336273
#
# 3000 step
#   Cost: 0.34936758875846863
#
# 3200 step
#   Cost: 0.33873772621154785
#
# 3400 step
#   Cost: 0.328634649515152
#
# 3600 step
#   Cost: 0.3190270960330963
#
# 3800 step
#   Cost: 0.3098861873149872
#
# 4000 step
#   Cost: 0.30118486285209656
#
# 4200 step
#   Cost: 0.2928977310657501
#
# 4400 step
#   Cost: 0.2850010395050049
#
# 4600 step
# ...

# %% [markdown]
# - tf.cast(True/False, dtype=tf.float32) : 첫 번째 인자가 True 면 1, False 면 0 리턴

# %%
# tf.cast Example
p = tf.cast(True, dtype=tf.float32)
sess = tf.Session()
print(sess.run(p))
# Out:
# 1.0
