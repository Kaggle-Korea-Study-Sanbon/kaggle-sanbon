# %% [markdown]
# #1. 표본분포와 표준오차
#
# 모표준편차(상자의 표준편차)
#
# - 상자로부터 하나의 값을 추출할 때 이 값이 상자의 평균(모평균)으로부터 얼마나 떨어져 있는가를 나타내는 지표
#
# 표본표준편차(SD)
#
# - 표본 내 하나의 값이 표본평균과 얼마나 떨어져 있는가를 나타내는 지표.
#
# - 이는 상자의 표준편차에 대한 추정량임
#
# 표본평균의 표준오차(표본평균의 SE)
#
# - 추출한 값들의 평균(표본평균)이 모평균과 얼마나 떨어져 있는가를 나타내는 지표

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24b4111f-e452-4b37-9627-492e04794f6e" name="files[]" multiple disabled />
#      <output id="result-24b4111f-e452-4b37-9627-492e04794f6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.PNG to 1 (1).PNG
# Saving 2.PNG to 2 (1).PNG
# Saving 3.PNG to 3 (1).PNG
# Saving 4.PNG to 4 (1).PNG
# Saving 5.PNG to 5 (2).PNG
# Saving 6.PNG to 6.PNG
# Saving 7.PNG to 7.PNG

# %%
from IPython.display import Image
Image('1.PNG')

# %% [markdown]
# 표본분포(sampling distribution)
#
# - 표본평균의 표본분포란 표본평ㅇ균의 확률히스토그램을 말한다.
#
# - 표본평균을 얻는 과정을 무한히 반복(R) 시행하여 얻은 수없이 많은 표본평균들을 가지고 그린 표본평균의 히스토그램

# %%
Image('3.PNG')

# %% [markdown]
# - 표본크기(n)가 크면 중심극한정리에 의해 히스토그램이 정규 근사가 가능함

# %% [markdown]
# # 2.표본평균으로 모평균 추정하기
#
# - 개개인의 교육수준의 분포

# %%
Image('4.PNG')

# %% [markdown]
# - 첫번째 : 모집단의 분포
#
#
# - 두번째 : 표본의 분포(n = 400)
#
# - 세번째 : 표본평균의 확률 히스토그램(R^)
#
# n = 400 -> 큰 수 이므로 '중심극한정리' -> 정규분포에 근사

# %% [markdown]
# - 두 번째 그림의 중심을 이용하여 첫 번째 그림의 중심을 맞춘다 = 추론의 본질
#
# - 평균으로는 불충분 -> 반복을 만 번(R = 10000) -> 표본평균이 어떻게 변할지 판단
#
# - 세 번째 그림을 도구로 활용하여 두 번째 그림의 중심을 가지고 첫 번째 그림의 중심을 확률적으로 잡음

# %% [markdown]
# # 3. 표준오차
#
# - 표본평군과 모평균 사이에 확률오차만큼 차이 존재
#
# - 확률오차가 작으면 신뢰도가 높음/ 크면 신뢰도가 작음
#
# - 확률오차의 전반적 크기는 표준오차로부터 알 수 있다

# %% [markdown]
# #4. 귀무가설과 대립가설
#
# 귀무가설, null hypothesis, H0:
#
# - 차이는 우연이다. 상자의 평균은 0이다.
#
# 대립가설, alternative hypothesis, H1:
#
# - 차이는 실질적이다. 상자의 평균은 음수 or 양수이다.

# %% [markdown]
# # 5. 검정통계량과 유의수준
#
# 검정통계량
#
# - z-통계량 or t-통계량이 널리 사용
#
# - 이들의 통계량은 자료에서 얻은 통계치와 귀무가설 수치(실질적으로 구한 값)의 표준화된 차이

# %%
Image('5.PNG')

# %% [markdown]
# 그림에서의 기대값
#
# - 귀무가설 하에서 계산(실질적 계산 값)
#
# 분자의 의미
#
# - 이론과 실제의 차이
#
# - 차이가 크면 기각
#
# - 차이가 작으면 기각하지 않음
#
# - 분자의 절대적 차이는 무의미 -> 표준오차 사용(통계량에 전형적으로 들어 있는 오차의 크기)

# %% [markdown]
# 관측된 유의수준인 p- 값이 미리 설정한 기준보다 낮으면 귀무가설을 기각
#
# 가설 검정의 원리는 [모순에 의한 논증법]
#
# - p-값 ≤ 유의수준 -> H0 기각
#
# - p-값 > 유의수준 -> H0 기각 못함

# %% [markdown]
# 단측검정과 양측검정
#
# - 대립가설의 주장이 방향성을 가지면 단측검정
#
# - 대립가설의 주장이 방향성을 갖지 않으면 양측검정
#
# - ex)

# %%
Image('6.PNG')

# %% [markdown]
# - 대립가설의 형태에 따른 p-값

# %%
Image('7.PNG')
